# %%
import os
import subprocess
from cropper_custom import export_crops_from_custom

# %%
yolo_executable = '/Users/tee/Projects/pj1_car/venv/bin/yolo'

# Original dataset layout
images_train = '/Users/tee/Projects/pj1_car/data/yolo_sample/images/train'
labels_train = '/Users/tee/Projects/pj1_car/data/yolo_sample/labels/train' 
images_val   = '/Users/tee/Projects/pj1_car/data/yolo_sample/images/val'
labels_val   = '/Users/tee/Projects/pj1_car/data/yolo_sample/labels/val'

# Where the classification crops will be written (folder-per-class)
data_root = '/Users/afrazrupak/CarProject_dev/car_project_dev/yolo_cls_car_makes'
project_path = '/Users/afrazrupak/CarProject_dev/car_project_dev/runs/classify'
os.makedirs(project_path, exist_ok=True)
